# %%
import pandas as pd
import requests

# %%
url = 'https://api.geoapify.com/v2/places?categories=accommodation.hostel,accommodation.apartment&filter=circle:73.8544541,18.521428,5000&bias=proximity:73.8544541,18.521428&limit=20&apiKey=ef891cb05234432a9ee4e15e0689d394'
r = requests.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
json = r.json()
json
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'CPS asram',
#     'street': 'K. B. Joshi Path',
#     'suburb': 'Shivajinagar',
#     'city': 'Pune',
#     'county': 'Pune',
#     'state': 'Maharashtra',
#     'postcode': '411016',
#     'country': 'India',
#     'country_code': 'in',
#     'lon': 73.8488004,
#     'lat': 18.5338301,
#     'formatted': 'CPS asram, K. B. Joshi Path, Shivajinagar, Pune - 411016, Maharashtra, India',
#     'address_line1': 'CPS asram',
#     'address_line2': 'K. B. Joshi Path, Shivajinagar, Pune - 411016, Maharashtra, India',
#     'categories': ['accommodation', 'accommodation.hostel'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'osm_id': 5257379121,
#       'name:en': 'CPS asram',
# ...

# %%
json.keys()
# Out:
# dict_keys(['type', 'features'])

# %%
type(json['type'])
# Out:
# str

# %%
type(json['features'])
# Out:
# list

# %%
type(json['features'][0])
# Out:
# dict

# %%
df = pd.DataFrame(json['features'])

# %%
df
# Out:
#        type                                         properties  \
# 0   Feature  {'name': 'CPS asram', 'street': 'K. B. Joshi P...
# 1   Feature  {'name': 'Tilak ayurveda hostel', 'street': 'S...
# 2   Feature  {'name': 'bj gmc boys hostel', 'street': 'Susi...
# 3   Feature  {'name': 'Gokhale Institute of Politics & Econ...
# 4   Feature  {'name': 'Baramati Hostel (Boys)', 'street': '...
# 5   Feature  {'name': 'Main Girls Hostel', 'street': 'Range...
# 6   Feature  {'name': 'New Girls Hostel', 'street': 'Range ...
# 7   Feature  {'name': 'Main Boys Hostel', 'street': 'Range ...
# 8   Feature  {'name': 'New Boys Hostel', 'street': 'Range H...
# 9   Feature  {'name': 'Oakwood', 'housenumber': '1C', 'stre...
# 10  Feature  {'name': 'Saket', 'street': 'Patwardhan Baug P...
# 11  Feature  {'name': 'Bharat Vihar', 'street': 'Gulwani Ma...
# 12  Feature  {'name': 'Saumitra', 'street': 'Gulwani Mahara...
# 13  Feature  {'name': 'MIT Boys Hostel', 'street': 'Vasantr...
# ...

# %%
url = 'https://api.geoapify.com/v2/places?categories=commercial.marketplace,commercial.stationery,catering.restaurant,education.college,healthcare.clinic_or_praxis,parking.motorcycle,commercial.elektronics,catering.cafe&filter=circle:73.8266998542524,18.523943,5000&bias=proximity:73.8266998542524,18.523943&limit=20&apiKey=ef891cb05234432a9ee4e15e0689d394'
r = requests.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
json = r.json()
json
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'Baba Food Mall',
#     'street': 'Balshastri Jambhekar Marg',
#     'suburb': 'Model Colony',
#     'city': 'Pune',
#     'county': 'Pune',
#     'state': 'Maharashtra',
#     'postcode': '411053',
#     'country': 'India',
#     'country_code': 'in',
#     'lon': 73.82854747156051,
#     'lat': 18.52437305,
#     'formatted': 'Baba Food Mall, Balshastri Jambhekar Marg, Model Colony, Pune - 411053, Maharashtra, India',
#     'address_line1': 'Baba Food Mall',
#     'address_line2': 'Balshastri Jambhekar Marg, Model Colony, Pune - 411053, Maharashtra, India',
#     'categories': ['building',
#      'building.catering',
#      'catering',
#      'catering.restaurant'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
# ...

# %%
json.keys()
# Out:
# dict_keys(['type', 'features'])

# %%
type(json['type'])
# Out:
# str

# %%
type(json['features'])
# Out:
# list

# %%
type(json['features'][0])
# Out:
# dict

# %%
df = pd.DataFrame(json['features'])
df
# Out:
#        type                                         properties  \
# 0   Feature  {'name': 'Baba Food Mall', 'street': 'Balshast...
# 1   Feature  {'name': 'Symbiosis', 'street': 'Senapati Bapa...
# 2   Feature  {'name': 'Symbiosis Soceity Office', 'street':...
# 3   Feature  {'name': 'NCC Canteen', 'street': 'Senapati Ba...
# 4   Feature  {'name': 'Bhandarkar Oriental Research Institu...
# 5   Feature  {'name': 'ILS Law College', 'street': 'Prabhat...
# 6   Feature  {'name': 'German Bakery', 'street': 'Vishnusha...
# 7   Feature  {'name': 'Café Coffee Day', 'street': 'Vishnus...
# 8   Feature  {'name': 'Domino's', 'street': 'Senapati Bapat...
# 9   Feature  {'name': 'My Idea', 'street': 'Bhandarkar Path...
# 10  Feature  {'name': 'Mainland China', 'street': 'Bharatiy...
# 11  Feature  {'name': 'DR. AMEET DRAVID', 'housenumber': '7...
# 12  Feature  {'name': 'PMC - Dr. Homi J Bhabha Maternity Ho...
# 13  Feature  {'name': 'Maharashtra State Institute of Hotel...
# ...
